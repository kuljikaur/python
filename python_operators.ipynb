# %% [markdown]
# # aritmetic operators

# %%
a = 4
b = 2
print("sum = ", a+b)
print("multiple = ", a*b)
print("division = ", a/b) #this gives ans in float
print("division using double slash (floor division) = ", a//b)
print("modulus = ", a%b)
print("exponnetiation = ", a**b)
# Out:
# sum =  6
# multiple =  8
# division =  2.0
# division using double slash (floor division) =  2
# modulus =  0
# exponnetiation =  16
# sum =  6
# sum =  6

# %% [markdown]
# # comaprision operators , they always returns true and false

# %%
print("equal to \nreturnss true and false \n \n",a==b)
print("not equal to \nreturnss true and false \n \n",a!=b)
print("greater than \nreturnss true and false \n \n",a>b)
print("less than \nreturnss true and false \n \n",a<b)
print("greater than equal to \nreturnss true and false \n \n",a>=b)
print("less than equal to \nreturnss true and false \n \n",a<=b)
# Out:
# equal to
# returnss true and false
#
#  False
# not equal to
# returnss true and false
#
#  True
# greater than
# returnss true and false
#
#  True
# less than
# returnss true and false
#
#  False
# greater than equal to
# returnss true and false
#
#  True
# less than equal to
# returnss true and false
#
#  False

# %% [markdown]
# # logical operators

# %% [markdown]
# c=3
# d=4
# print("AND : returns last true value, if both given values holds some numeric data = ", c and d)
# print("Or : returns the first true value, and true if any of the variabe holds the numberic data  =  ", c or d)
# print("not b : returns opposite of any of the number  ", not c)

# %% [markdown]
# # bitwise operator

# %%
#only & and | 

e = 3 # 011 (binary)
f = 4 ## 100 (binary) 

# it add the data values by bits  , 110+100 = 000
print("the bitwise and , doing and operation :",c & d)  # output = 0 
print("the bitwise or m performs addition biwise: ",c|d) # its return 111 = 7
# Out:
# the bitwise and , doing and operation : 0
# the bitwise or m performs addition biwise:  7

# %% [markdown]
# # assignmnt operators

# %%
z = 4
print(z)
z += 4 # z = z+4
print(z)

z-= 2 #z = z-8 = 6
print(z)

z *= 2 # z = 6*2 = 12
print(z)

z /= 2 # z =
print(z)

z //= 2 #z = z-8 = 6
print(z)
# Out:
# 4
# 8
# 6
# 12
# 6.0
# 3.0

# %% [markdown]
# # membership operators

# %%
lst = [1,2,3,4,5]

x=7
i=5

print(2 in lst) #tells whether 2 is present in the list or not 

print(10 not in lst) # not in , operator returns true if some letter or digit is not present in the lst 

print(x is i) # returns true if objects are same
print(x is not i ) # returns ture if obejct are not same
# Out:
# True
# True
# False
# True

# %% [markdown]
# # operator precedence

# %% [markdown]
# # for operating the operating ,  python follows PEMDAS (parenthesis, exponentiation, multiplication/division, addition/subtraction )

# %%
result = 10+2*3  # fisrt multiplication solve, 6+10 = 16
print(result)

result2 = (10+2)*3 # parenthesis solve, 12*3 = 36
print(result2)

result3 = 10**2**3 # it goes right to left , first 2**3 = 8  , 10**8 = 100000000
print(result3)
# Out:
# 16
# 36
# 100000000

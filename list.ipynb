# %% [markdown]
# #### finding a largest elemnt in list

# %% [markdown]
# for finding largest number in a list, in string, in a number , first consider any number, so that we can compare all the number with that considered number....

# %%
lis = [23,45,67,89,12]
largest = lis[0]

for i in lis:
    if i > largest :
        largest = i 

print("the largets no. in the list is : ", largest )
# Out:
# the largets no. in the lsit is :  89

# %% [markdown]
# #### finding a smaller number in list

# %%
lis2 = [2,4,5]
smaller = lis2[0]

for j in lis2:
    if smaller > j :
        smaller = j 

print(smaller)
# Out:
# 2

# %% [markdown]
# #### appending a number in a list

# %%
# use extend function to add anything in the list 
# take element you want to add in the list, but take in the square braces..........

# %%
lisss = [2,3,4,6]
element = [10]
lisss.extend(element)
print(lisss)
# Out:
# [2, 3, 4, 6, 10]
